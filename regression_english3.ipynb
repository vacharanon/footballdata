# %%
# %matplotlib inline
import os
import operator
import numpy as np
import pandas as pd
from football_loader import metrics


def load_league_csv(league, start_year=2005):
    df = None
    files = os.listdir(f'fulldata/{league}')
    files.sort()
    for file in files:
        year = int(file.strip('.csv'))
        if year < start_year:
            continue
        df_year = pd.read_csv(f'fulldata/{league}/' + file,
                              engine='python',
                              # skiprows=1,
                              # index_col=None,
                              # names=['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A']
                              )
        df_year.reset_index(drop=True, inplace=True)
        df_year['Year'] = year
        df_year['Match'] = df_year.index + 1

        if df is None:
            df = df_year
        else:
            df = df.append(df_year, ignore_index=True, sort=False)

    # print(len(df))
    # print(df.shape)

    # remove unused columns
    # df_league = None
    df.reset_index(inplace=True)
    # df = df[['Year', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR',
    #          "B365H", "B365D", "B365A"]]
    return df


def make_features(df, teams, train_year, validate_year, test_year):
    # df_league = None
    ret = {}

    # if teams is None:
    #     teams = np.unique(df.loc[df['Year'] == predict_year, 'HomeTeam'].values)
    #     teams.sort()
    for team in teams:

        df_team = df[(df['HomeTeam'] == team) | (df['AwayTeam'] == team)]
        all = pd.DataFrame(
            data={
                'Year': df_team['Year'],
                'Date': df_team['Date'],
                'Team': team,
                'HomeMatch': df_team['HomeTeam'] == team
            }
        )
        all['Opponent'] = np.where(all['HomeMatch'], df_team['AwayTeam'], df_team['HomeTeam'])
        # X['HalfTimeGoals'] = np.where(X['HomeMatch'], df_team['HTHG'], df_team['HTAG'])
        # X['HalfTimeOpponentGoals'] = np.where(X['HomeMatch'], df_team['HTAG'], df_team['HTHG'])
        # X['HalfTimeLead'] = X['HalfTimeGoals'] > X['HalfTimeOpponentGoals']
        # X['HalfTimeLeadMoreThanTwo'] = (X['HalfTimeGoals'] - X['HalfTimeOpponentGoals']) > 2
        # X['FullTimeGoals'] = np.where(X['HomeMatch'], ath_madrid['FTHG'], ath_madrid['FTAG'])
        # X['FullTimeOpponentGoals'] = np.where(X['HomeMatch'], ath_madrid['FTAG'], ath_madrid['FTHG'])
        all['FTR'] = df_team['FTR']
        all['Won'] = np.where(all['HomeMatch'], df_team['FTR'] == 'H', df_team['FTR'] == 'A')
        all['Draw'] = df_team['FTR'] == 'D'
        all['Lost'] = np.where(all['HomeMatch'], df_team['FTR'] == 'A', df_team['FTR'] == 'H')
        all['Result'] = np.where(all['Won'], 'Win', (np.where(all['Lost'], 'Lose', 'Draw')))
        # X['SumGoals'] = X.groupby('Opponent')['FullTimeGoals'].transform(sum)
        all['B365Max'] = np.maximum(np.maximum(df_team['B365H'], df_team['B365A']), df_team['B365D'])
        all['B365Min'] = np.minimum(np.minimum(df_team['B365H'], df_team['B365A']), df_team['B365D'])
        all['B365Say'] = np.where(all['HomeMatch'],
                                  # home match
                                  np.where(all['B365Max'] == df_team['B365H'], -1,
                                           np.where(all['B365Max'] == df_team['B365A'], 1,
                                                    0)),
                                  # away match
                                  np.where(all['B365Max'] == df_team['B365H'], 1,
                                           np.where(all['B365Max'] == df_team['B365A'], -1,
                                                    0))
                                  )
        all['B365Diff'] = np.where(all['B365Say'] == 1, all['B365Max'] - all['B365Min'],
                                   all['B365Min'] - all['B365Max'])
        all['Corners'] = np.where(all['HomeMatch'], df_team['HC'], df_team['AC'])
        all['Shots'] = np.where(all['HomeMatch'], df_team['HS'], df_team['AS'])
        all['ShotsOnTarget'] = np.where(all['HomeMatch'], df_team['HST'], df_team['AST'])
        all['Points'] = np.where(all['Won'], 3,
                                 np.where(all['Draw'], 1, 0)
                                  )
        all['AdjustedPoints'] = np.where(all['HomeMatch'],
                                  # home match
                                         np.where(all['Won'], 1,
                                                  np.where(all['Draw'], 0, -1)
                                                  )
                                         ,
                                  # away match
                                         np.where(all['Won'], 1.5,
                                                  np.where(all['Draw'], 0.5, 0)
                                                  )
                                  )

        # find number of times won against this opponent in last 5 meetings
        for key, groupByOpponent in all.groupby('Opponent'):
            # keep index as new a column, will be restored and assigned back to X later
            idx = groupByOpponent.index

            # make match day an index because rolling need an index date
            xx = groupByOpponent.set_index('Date')
            xx['idx'] = idx
            # shift to exclude self
            xx['Last5AgainstThisOpponentWon'] = xx['Won'].rolling(6).apply(lambda x: np.nansum(x.shift()), raw=False)
            xx['Last5AgainstThisOpponentDraw'] = xx['Draw'].rolling(6).apply(lambda x: np.nansum(x.shift()), raw=False)
            # xx['Last5AgainstThisOpponentLost'] = xx['Lost'].rolling(6).apply(lambda x: np.nansum(x.shift()), raw=False)

            xx['Last3AgainstThisOpponentWon'] = xx['Won'].rolling(4).apply(lambda x: np.nansum(x.shift()), raw=False)
            xx['Last3AgainstThisOpponentDraw'] = xx['Draw'].rolling(4).apply(lambda x: np.nansum(x.shift()), raw=False)

            xx['LastAgainstThisOpponentWon'] = xx['Won'].rolling(2).apply(lambda x: np.nansum(x.shift()), raw=False)
            xx['LastAgainstThisOpponentDraw'] = xx['Draw'].rolling(2).apply(lambda x: np.nansum(x.shift()), raw=False)
            # xx['LastThisOpponentLost'] = xx['Lost'].rolling(2).apply(lambda x: np.nansum(x.shift()), raw=False)

            # restore index
            xx = xx.set_index('idx')

            # assign back to the big dataframe
            all.loc[xx.index, 'Last5AgainstThisOpponentWon'] = xx['Last5AgainstThisOpponentWon']
            all.loc[xx.index, 'Last5AgainstThisOpponentDraw'] = xx['Last5AgainstThisOpponentDraw']
            # X.loc[xx.index, 'Last5AgainstThisOpponentLost'] = xx['Last5AgainstThisOpponentLost']
            all.loc[xx.index, 'Last3AgainstThisOpponentWon'] = xx['Last3AgainstThisOpponentWon']
            all.loc[xx.index, 'Last3AgainstThisOpponentDraw'] = xx['Last3AgainstThisOpponentDraw']
            all.loc[xx.index, 'LastAgainstThisOpponentWon'] = xx['LastAgainstThisOpponentWon']
            all.loc[xx.index, 'LastAgainstThisOpponentDraw'] = xx['LastAgainstThisOpponentDraw']
            # X.loc[xx.index, 'LastThisOpponentLost'] = xx['LastThisOpponentLost']

        # stats by year/season
        for year, groupByYear in all.groupby('Year'):
            # print(year)
            # keep index as new a column, will be restored and assigned back to X later
            idx = groupByYear.index

            # make match day an index because rolling need an index date
            xx = groupByYear.set_index('Date')
            xx['idx'] = idx

            # shift to exclude self
            xx['CornersSoFar'] = np.nancumsum(xx['Corners'].shift())
            xx['ShotsSoFar'] = np.nancumsum(xx['Shots'].shift())
            xx['ShotsOnTargetSoFar'] = np.nancumsum(xx['ShotsOnTarget'].shift())

            xx['HomeWonNum'] = np.where(xx['HomeMatch'] & xx['Won'], 1, 0)
            xx['HomeWonSoFar'] = np.nancumsum(xx['HomeWonNum'].shift())
            xx['AwayWonNum'] = np.where((xx['HomeMatch'] == False) & xx['Won'], 1, 0)
            xx['AwayWonSoFar'] = np.nancumsum(xx['AwayWonNum'].shift())

            xx['PointsSoFar'] = np.nancumsum(xx['Points'].shift())
            xx['AdjustedPointsSoFar'] = np.nancumsum(xx['AdjustedPoints'].shift())

            # restore index
            xx = xx.set_index('idx')

            # assign back to the big dataframe
#             all.loc[xx.index, 'CornersSoFar'] = xx['CornersSoFar']
#             all.loc[xx.index, 'ShotsSoFar'] = xx['ShotsSoFar']
#             all.loc[xx.index, 'ShotsOnTargetSoFar'] = xx['ShotsOnTargetSoFar']
#             all.loc[xx.index, 'HomeWonSoFar'] = xx['HomeWonSoFar']
#             all.loc[xx.index, 'AwayWonSoFar'] = xx['AwayWonSoFar']
            all.loc[xx.index, 'PointsSoFar'] = xx['PointsSoFar']
            all.loc[xx.index, 'AdjustedPointsSoFar'] = xx['AdjustedPointsSoFar']

        # find recent forms
        idx = all.index
        xx = all.set_index('Date')
        xx['idx'] = idx
        xx['Last5Won'] = xx['Won'].rolling(6).apply(lambda x: np.nansum(x.shift()), raw=False)
        xx['Last5Draw'] = xx['Draw'].rolling(6).apply(lambda x: np.nansum(x.shift()), raw=False)
        # xx['Last5Lost'] = xx['Lost'].rolling(6).apply(lambda x: np.nansum(x.shift()), raw=False)
        xx['Last3Won'] = xx['Won'].rolling(4).apply(lambda x: np.nansum(x.shift()), raw=False)
        xx['Last3Draw'] = xx['Draw'].rolling(4).apply(lambda x: np.nansum(x.shift()), raw=False)
        xx['LastWon'] = xx['Won'].rolling(2).apply(lambda x: np.nansum(x.shift()), raw=False)
        xx['LastDraw'] = xx['Draw'].rolling(2).apply(lambda x: np.nansum(x.shift()), raw=False)

        # restore index
        xx = xx.set_index('idx')
        # assign back to the big dataframe
        all.loc[xx.index, 'Last5Won'] = xx['Last5Won']
        all.loc[xx.index, 'Last5Draw'] = xx['Last5Draw']
        all.loc[xx.index, 'Last3Won'] = xx['Last3Won']
        all.loc[xx.index, 'Last3Draw'] = xx['Last3Draw']
        all.loc[xx.index, 'LastWon'] = xx['LastWon']
        all.loc[xx.index, 'LastDraw'] = xx['LastDraw']
        # X.loc[xx.index, 'Last5Lost'] = xx['Last5Lost']

        # replace nan with 0
        # TODO: better way to handle nan
        all.loc[np.isnan(all['Last5AgainstThisOpponentWon']), 'Last5AgainstThisOpponentWon'] = 0
        all.loc[np.isnan(all['Last5AgainstThisOpponentDraw']), 'Last5AgainstThisOpponentDraw'] = 0
        # X.loc[np.isnan(X['Last5AgainstThisOpponentLost']), 'Last5AgainstThisOpponentLost'] = 0
        all.loc[np.isnan(all['Last3AgainstThisOpponentWon']), 'Last3AgainstThisOpponentWon'] = 0
        all.loc[np.isnan(all['Last3AgainstThisOpponentDraw']), 'Last3AgainstThisOpponentDraw'] = 0
        all.loc[np.isnan(all['LastAgainstThisOpponentWon']), 'LastAgainstThisOpponentWon'] = 0
        all.loc[np.isnan(all['LastAgainstThisOpponentDraw']), 'LastAgainstThisOpponentDraw'] = 0
        # X.loc[np.isnan(X['LastThisOpponentLost']), 'LastThisOpponentLost'] = 0
        all.loc[np.isnan(all['Last5Won']), 'Last5Won'] = 0
        all.loc[np.isnan(all['Last5Draw']), 'Last5Draw'] = 0
        # X.loc[np.isnan(X['Last5Lost']), 'Last5Lost'] = 0
        all.loc[np.isnan(all['Last3Won']), 'Last3Won'] = 0
        all.loc[np.isnan(all['Last3Draw']), 'Last3Draw'] = 0
        all.loc[np.isnan(all['LastWon']), 'LastWon'] = 0
        all.loc[np.isnan(all['LastDraw']), 'LastDraw'] = 0

        # restrict training data (too old data may not be irrelevance)
        X = all
        Y = X[['Result']]
        # del X['Result']
        # X = all.loc[(all['Year'] >= train_year) & (all['Year'] < predict_year)]
        # Y = all[['Result']]

        # split data into train - test sets
        # x_train = X[(X['Year'] < predict_year)]
        # y_train = Y[(X['Year'] < predict_year)]
        # x_test = X[(X['Year'] >= predict_year)]
        # y_test = Y[(X['Year'] >= predict_year)]
        # X['Predict'] = ''
        close_leaks(X)
        ret[team] = [X, Y]
    return ret


# call this after you've split data
def close_leaks(X):
    # remove duplicate features
    del X['LastWon']
    del X['LastDraw']

    # prevent future leaks
    # result = pd.DataFrame(X['Result'])
    del X['Result']
    del X['Lost']
    del X['Draw']
    del X['Won']
    del X['FTR']
    del X['Date']
    del X['Opponent']
    del X['Team']
    del X['B365Max']
    del X['B365Min']
    del X['Corners']
    del X['Shots']
    del X['ShotsOnTarget']
    del X['Points']
    del X['AdjustedPoints']

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,BaggingClassifier,ExtraTreesClassifier,GradientBoostingClassifier
import numpy as np
from sklearn import svm
from sklearn.multiclass import OneVsRestClassifier

# %%
league = 'english'
validate_year = 2016
test_year = 2017
train_year = 2011
# train_year = 2009
df = load_league_csv(league)

# %%
teams = df.loc[(df['Year'] == validate_year) | (df['Year'] == test_year), 'HomeTeam']
teams = teams.unique()
teams.sort()
print(teams)
print(len(teams))
# Out:
# ['Arsenal' 'Bournemouth' 'Brighton' 'Burnley' 'Chelsea' 'Crystal Palace'
#  'Everton' 'Huddersfield' 'Hull' 'Leicester' 'Liverpool' 'Man City'
#  'Man United' 'Middlesbrough' 'Newcastle' 'Southampton' 'Stoke'
#  'Sunderland' 'Swansea' 'Tottenham' 'Watford' 'West Brom' 'West Ham']
# 23

# %%
teams = make_features(df, teams, train_year, validate_year, test_year)
classes = ['Draw', 'Lose', 'Win']

# %%
print('X')
print(teams['Arsenal'][0].count()) # X
print('Y')
print(teams['Arsenal'][1].count()) # Y
# Out:
# X
# Year                            494
# HomeMatch                       494
# B365Say                         494
# B365Diff                        494
# Last5AgainstThisOpponentWon     494
# Last5AgainstThisOpponentDraw    494
# Last3AgainstThisOpponentWon     494
# Last3AgainstThisOpponentDraw    494
# LastAgainstThisOpponentWon      494
# LastAgainstThisOpponentDraw     494
# PointsSoFar                     494
# AdjustedPointsSoFar             494
# Last5Won                        494
# Last5Draw                       494
# Last3Won                        494
# Last3Draw                       494
# dtype: int64
# Y
# Result    494
# dtype: int64

# %%
total = None
for team in teams:
# for team in ['Arsenal']:
    X = teams[team][0]
    Y = teams[team][1]
    # split data into train - validate - test sets
    x_train = X[(X['Year'] < validate_year)]
    y_train = Y[(X['Year'] < validate_year)]
    x_validate = X[(X['Year'] >= validate_year) & (X['Year'] < test_year)]
    y_validate = Y[(X['Year'] >= validate_year) & (X['Year'] < test_year)]
    x_test = X[(X['Year'] >= test_year)]
    y_test = Y[(X['Year'] >= test_year)]
    if len(x_train) <= 0 or len(x_test) <= 0 or len(x_validate) <= 0:
        print(f'skip {team}')
        continue
    
    validate_accuracies = {}
    test_accuracies = {}
    
    lr = LogisticRegression()
    lr.fit(x_train, y_train['Result'])
    y_validate_pred = lr.predict(x_validate)
    validate_accuracies['LogisticRegression'] = accuracy_score(y_validate, y_validate_pred) * 100
    y_test_pred = lr.predict(x_test)
    test_accuracies['LogisticRegression'] = accuracy_score(y_test, y_test_pred) * 100
    d = pd.DataFrame(
        data={
            'pred': y_test_pred,
            'actual': y_test['Result'].values
        },
        index=pd.MultiIndex.from_tuples(
            list(zip(np.repeat('LogisticRegression', len(y_test.index)), y_test.index.values)),
            names=['predictor', 'match_id'])
    )
    if total is None:
        total = d
    else:
        total = total.append(d)
    
    rfc = RandomForestClassifier(n_estimators=10)
    rfc.fit(x_train, y_train['Result'])
    y_validate_pred = rfc.predict(x_validate)
    validate_accuracies['RandomForestClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    y_test_pred = rfc.predict(x_test)
    test_accuracies['RandomForestClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    d = pd.DataFrame(
        data={
            'pred': y_test_pred,
            'actual': y_test['Result'].values
        },
        index=pd.MultiIndex.from_tuples(
            list(zip(np.repeat('RandomForestClassifier', len(y_test.index)), y_test.index.values)),
            names=['predictor', 'match_id'])
    )
    if total is None:
        total = d
    else:
        total = total.append(d)
    
    abc = AdaBoostClassifier()
    abc.fit(x_train, y_train['Result'])
    y_validate_pred = abc.predict(x_validate)
    validate_accuracies['AdaBoostClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    y_test_pred = abc.predict(x_test)
    test_accuracies['AdaBoostClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    d = pd.DataFrame(
        data={
            'pred': y_test_pred,
            'actual': y_test['Result'].values
        },
        index=pd.MultiIndex.from_tuples(
            list(zip(np.repeat('AdaBoostClassifier', len(y_test.index)), y_test.index.values)),
            names=['predictor', 'match_id'])
    )
    if total is None:
        total = d
    else:
        total = total.append(d)
        
    bc = BaggingClassifier()
    bc.fit(x_train, y_train['Result'])
    y_validate_pred = bc.predict(x_validate)
    validate_accuracies['BaggingClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    y_test_pred = bc.predict(x_test)
    test_accuracies['BaggingClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    d = pd.DataFrame(
        data={
            'pred': y_test_pred,
            'actual': y_test['Result'].values
        },
        index=pd.MultiIndex.from_tuples(
            list(zip(np.repeat('BaggingClassifier', len(y_test.index)), y_test.index.values)),
            names=['predictor', 'match_id'])
    )
    if total is None:
        total = d
    else:
        total = total.append(d)
        
    etc = ExtraTreesClassifier()
    etc.fit(x_train, y_train['Result'])
    y_validate_pred = etc.predict(x_validate)
    validate_accuracies['ExtraTreesClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    y_test_pred = etc.predict(x_test)
    test_accuracies['ExtraTreesClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    d = pd.DataFrame(
        data={
            'pred': y_test_pred,
            'actual': y_test['Result'].values
        },
        index=pd.MultiIndex.from_tuples(
            list(zip(np.repeat('ExtraTreesClassifier', len(y_test.index)), y_test.index.values)),
            names=['predictor', 'match_id'])
    )
    if total is None:
        total = d
    else:
        total = total.append(d)
        
    gbc = GradientBoostingClassifier()
    gbc.fit(x_train, y_train['Result'])
    y_validate_pred = gbc.predict(x_validate)
    validate_accuracies['GradientBoostingClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    y_test_pred = gbc.predict(x_test)
    test_accuracies['GradientBoostingClassifier'] = accuracy_score(y_validate, y_validate_pred) * 100
    d = pd.DataFrame(
        data={
            'pred': y_test_pred,
            'actual': y_test['Result'].values
        },
        index=pd.MultiIndex.from_tuples(
            list(zip(np.repeat('GradientBoostingClassifier', len(y_test.index)), y_test.index.values)),
            names=['predictor', 'match_id'])
    )
    if total is None:
        total = d
    else:
        total = total.append(d)
    
    for (k, v) in validate_accuracies.items():
        print(f"{k}: {team} validation accuracy are: {v}")
        print(f"{k}: {team} test accuracy are: {test_accuracies[k]}")

    best = max(validate_accuracies.items(), key=operator.itemgetter(1))
    print('***Best validate classifier is', best[0], best[1])
    best = max(test_accuracies.items(), key=operator.itemgetter(1))
    print('***Best test classifier is', best[0], best[1])
    print('-------------------------')
#     print(f"LogisticRegression: {team} validation accuracy are: ", accuracy_score(y_validate, y_validate_pred) * 100)
#     print(f"LogisticRegression: {team} test accuracy are: ", accuracy_score(y_test, y_test_pred) * 100)
#     cm = confusion_matrix(y_validate, y_validate_pred, labels=classes)
#     metrics.plot_confusion_matrix(cm, classes, title=team)
    
    if total is None:
        total = d
    else:
        total = total.append(d)
# Out:
# LogisticRegression: Arsenal validation accuracy are: 63.1578947368421
# LogisticRegression: Arsenal test accuracy are: 60.526315789473685
# RandomForestClassifier: Arsenal validation accuracy are: 55.26315789473685
# RandomForestClassifier: Arsenal test accuracy are: 55.26315789473685
# AdaBoostClassifier: Arsenal validation accuracy are: 44.73684210526316
# AdaBoostClassifier: Arsenal test accuracy are: 44.73684210526316
# BaggingClassifier: Arsenal validation accuracy are: 50.0
# BaggingClassifier: Arsenal test accuracy are: 50.0
# ExtraTreesClassifier: Arsenal validation accuracy are: 65.78947368421053
# ExtraTreesClassifier: Arsenal test accuracy are: 65.78947368421053
# GradientBoostingClassifier: Arsenal validation accuracy are: 42.10526315789473
# GradientBoostingClassifier: Arsenal test accuracy are: 42.10526315789473
# ***Best validate classifier is ExtraTreesClassifier 65.78947368421053
# ***Best test classifier is ExtraTreesClassifier 65.78947368421053
# -------------------------
# LogisticRegression: Bournemouth validation accuracy are: 57.89473684210527
# LogisticRegression: Bournemouth test accuracy are: 47.368421052631575
# RandomForestClassifier: Bournemouth validation accuracy are: 42.10526315789473
# RandomForestClassifier: Bournemouth test accuracy are: 42.10526315789473
# AdaBoostClassifier: Bournemouth validation accuracy are: 36.84210526315789
# AdaBoostClassifier: Bournemouth test accuracy are: 36.84210526315789
# BaggingClassifier: Bournemouth validation accuracy are: 47.368421052631575
# BaggingClassifier: Bournemouth test accuracy are: 47.368421052631575
# ExtraTreesClassifier: Bournemouth validation accuracy are: 42.10526315789473
# ExtraTreesClassifier: Bournemouth test accuracy are: 42.10526315789473
# GradientBoostingClassifier: Bournemouth validation accuracy are: 31.57894736842105
# GradientBoostingClassifier: Bournemouth test accuracy are: 31.57894736842105
# ***Best validate classifier is LogisticRegression 57.89473684210527
# ***Best test classifier is LogisticRegression 47.368421052631575
# -------------------------
# skip Brighton
# LogisticRegression: Burnley validation accuracy are: 50.0
# LogisticRegression: Burnley test accuracy are: 39.473684210526315
# RandomForestClassifier: Burnley validation accuracy are: 52.63157894736842
# RandomForestClassifier: Burnley test accuracy are: 52.63157894736842
# AdaBoostClassifier: Burnley validation accuracy are: 42.10526315789473
# AdaBoostClassifier: Burnley test accuracy are: 42.10526315789473
# BaggingClassifier: Burnley validation accuracy are: 52.63157894736842
# BaggingClassifier: Burnley test accuracy are: 52.63157894736842
# ExtraTreesClassifier: Burnley validation accuracy are: 39.473684210526315
# ExtraTreesClassifier: Burnley test accuracy are: 39.473684210526315
# GradientBoostingClassifier: Burnley validation accuracy are: 42.10526315789473
# GradientBoostingClassifier: Burnley test accuracy are: 42.10526315789473
# ***Best validate classifier is RandomForestClassifier 52.63157894736842
# ***Best test classifier is RandomForestClassifier 52.63157894736842
# -------------------------
# LogisticRegression: Chelsea validation accuracy are: 81.57894736842105
# LogisticRegression: Chelsea test accuracy are: 52.63157894736842
# RandomForestClassifier: Chelsea validation accuracy are: 44.73684210526316
# RandomForestClassifier: Chelsea test accuracy are: 44.73684210526316
# AdaBoostClassifier: Chelsea validation accuracy are: 52.63157894736842
# AdaBoostClassifier: Chelsea test accuracy are: 52.63157894736842
# BaggingClassifier: Chelsea validation accuracy are: 42.10526315789473
# BaggingClassifier: Chelsea test accuracy are: 42.10526315789473
# ExtraTreesClassifier: Chelsea validation accuracy are: 31.57894736842105
# ExtraTreesClassifier: Chelsea test accuracy are: 31.57894736842105
# GradientBoostingClassifier: Chelsea validation accuracy are: 26.31578947368421
# GradientBoostingClassifier: Chelsea test accuracy are: 26.31578947368421
# ***Best validate classifier is LogisticRegression 81.57894736842105
# ***Best test classifier is LogisticRegression 52.63157894736842
# -------------------------
# LogisticRegression: Crystal Palace validation accuracy are: 44.73684210526316
# LogisticRegression: Crystal Palace test accuracy are: 50.0
# RandomForestClassifier: Crystal Palace validation accuracy are: 42.10526315789473
# RandomForestClassifier: Crystal Palace test accuracy are: 42.10526315789473
# AdaBoostClassifier: Crystal Palace validation accuracy are: 47.368421052631575
# AdaBoostClassifier: Crystal Palace test accuracy are: 47.368421052631575
# BaggingClassifier: Crystal Palace validation accuracy are: 36.84210526315789
# BaggingClassifier: Crystal Palace test accuracy are: 36.84210526315789
# ExtraTreesClassifier: Crystal Palace validation accuracy are: 39.473684210526315
# ExtraTreesClassifier: Crystal Palace test accuracy are: 39.473684210526315
# GradientBoostingClassifier: Crystal Palace validation accuracy are: 42.10526315789473
# GradientBoostingClassifier: Crystal Palace test accuracy are: 42.10526315789473
# ***Best validate classifier is AdaBoostClassifier 47.368421052631575
# ***Best test classifier is LogisticRegression 50.0
# -------------------------
# LogisticRegression: Everton validation accuracy are: 44.73684210526316
# LogisticRegression: Everton test accuracy are: 71.05263157894737
# RandomForestClassifier: Everton validation accuracy are: 39.473684210526315
# RandomForestClassifier: Everton test accuracy are: 39.473684210526315
# AdaBoostClassifier: Everton validation accuracy are: 47.368421052631575
# AdaBoostClassifier: Everton test accuracy are: 47.368421052631575
# BaggingClassifier: Everton validation accuracy are: 50.0
# BaggingClassifier: Everton test accuracy are: 50.0
# ExtraTreesClassifier: Everton validation accuracy are: 50.0
# ExtraTreesClassifier: Everton test accuracy are: 50.0
# GradientBoostingClassifier: Everton validation accuracy are: 50.0
# GradientBoostingClassifier: Everton test accuracy are: 50.0
# ***Best validate classifier is BaggingClassifier 50.0
# ***Best test classifier is LogisticRegression 71.05263157894737
# -------------------------
# skip Huddersfield
# skip Hull
# LogisticRegression: Leicester validation accuracy are: 42.10526315789473
# LogisticRegression: Leicester test accuracy are: 42.10526315789473
# RandomForestClassifier: Leicester validation accuracy are: 28.947368421052634
# RandomForestClassifier: Leicester test accuracy are: 28.947368421052634
# AdaBoostClassifier: Leicester validation accuracy are: 39.473684210526315
# AdaBoostClassifier: Leicester test accuracy are: 39.473684210526315
# BaggingClassifier: Leicester validation accuracy are: 39.473684210526315
# BaggingClassifier: Leicester test accuracy are: 39.473684210526315
# ExtraTreesClassifier: Leicester validation accuracy are: 42.10526315789473
# ExtraTreesClassifier: Leicester test accuracy are: 42.10526315789473
# GradientBoostingClassifier: Leicester validation accuracy are: 28.947368421052634
# GradientBoostingClassifier: Leicester test accuracy are: 28.947368421052634
# ***Best validate classifier is LogisticRegression 42.10526315789473
# ***Best test classifier is LogisticRegression 42.10526315789473
# -------------------------
# LogisticRegression: Liverpool validation accuracy are: 47.368421052631575
# LogisticRegression: Liverpool test accuracy are: 60.526315789473685
# RandomForestClassifier: Liverpool validation accuracy are: 28.947368421052634
# RandomForestClassifier: Liverpool test accuracy are: 28.947368421052634
# AdaBoostClassifier: Liverpool validation accuracy are: 36.84210526315789
# AdaBoostClassifier: Liverpool test accuracy are: 36.84210526315789
# BaggingClassifier: Liverpool validation accuracy are: 36.84210526315789
# BaggingClassifier: Liverpool test accuracy are: 36.84210526315789
# ExtraTreesClassifier: Liverpool validation accuracy are: 39.473684210526315
# ExtraTreesClassifier: Liverpool test accuracy are: 39.473684210526315
# GradientBoostingClassifier: Liverpool validation accuracy are: 36.84210526315789
# GradientBoostingClassifier: Liverpool test accuracy are: 36.84210526315789
# ***Best validate classifier is LogisticRegression 47.368421052631575
# ***Best test classifier is LogisticRegression 60.526315789473685
# -------------------------
# LogisticRegression: Man City validation accuracy are: 63.1578947368421
# LogisticRegression: Man City test accuracy are: 78.94736842105263
# RandomForestClassifier: Man City validation accuracy are: 50.0
# RandomForestClassifier: Man City test accuracy are: 50.0
# AdaBoostClassifier: Man City validation accuracy are: 63.1578947368421
# AdaBoostClassifier: Man City test accuracy are: 63.1578947368421
# BaggingClassifier: Man City validation accuracy are: 50.0
# BaggingClassifier: Man City test accuracy are: 50.0
# ExtraTreesClassifier: Man City validation accuracy are: 39.473684210526315
# ExtraTreesClassifier: Man City test accuracy are: 39.473684210526315
# GradientBoostingClassifier: Man City validation accuracy are: 47.368421052631575
# GradientBoostingClassifier: Man City test accuracy are: 47.368421052631575
# ***Best validate classifier is LogisticRegression 63.1578947368421
# ***Best test classifier is LogisticRegression 78.94736842105263
# -------------------------
# LogisticRegression: Man United validation accuracy are: 55.26315789473685
# LogisticRegression: Man United test accuracy are: 65.78947368421053
# RandomForestClassifier: Man United validation accuracy are: 39.473684210526315
# RandomForestClassifier: Man United test accuracy are: 39.473684210526315
# AdaBoostClassifier: Man United validation accuracy are: 39.473684210526315
# AdaBoostClassifier: Man United test accuracy are: 39.473684210526315
# BaggingClassifier: Man United validation accuracy are: 39.473684210526315
# BaggingClassifier: Man United test accuracy are: 39.473684210526315
# ExtraTreesClassifier: Man United validation accuracy are: 34.21052631578947
# ExtraTreesClassifier: Man United test accuracy are: 34.21052631578947
# GradientBoostingClassifier: Man United validation accuracy are: 50.0
# GradientBoostingClassifier: Man United test accuracy are: 50.0
# ***Best validate classifier is LogisticRegression 55.26315789473685
# ***Best test classifier is LogisticRegression 65.78947368421053
# -------------------------
# skip Middlesbrough
# skip Newcastle
# LogisticRegression: Southampton validation accuracy are: 55.26315789473685
# LogisticRegression: Southampton test accuracy are: 44.73684210526316
# RandomForestClassifier: Southampton validation accuracy are: 42.10526315789473
# RandomForestClassifier: Southampton test accuracy are: 42.10526315789473
# AdaBoostClassifier: Southampton validation accuracy are: 44.73684210526316
# AdaBoostClassifier: Southampton test accuracy are: 44.73684210526316
# BaggingClassifier: Southampton validation accuracy are: 42.10526315789473
# BaggingClassifier: Southampton test accuracy are: 42.10526315789473
# ExtraTreesClassifier: Southampton validation accuracy are: 34.21052631578947
# ExtraTreesClassifier: Southampton test accuracy are: 34.21052631578947
# GradientBoostingClassifier: Southampton validation accuracy are: 55.26315789473685
# GradientBoostingClassifier: Southampton test accuracy are: 55.26315789473685
# ***Best validate classifier is LogisticRegression 55.26315789473685
# ***Best test classifier is GradientBoostingClassifier 55.26315789473685
# -------------------------
# LogisticRegression: Stoke validation accuracy are: 50.0
# LogisticRegression: Stoke test accuracy are: 34.21052631578947
# RandomForestClassifier: Stoke validation accuracy are: 39.473684210526315
# RandomForestClassifier: Stoke test accuracy are: 39.473684210526315
# AdaBoostClassifier: Stoke validation accuracy are: 50.0
# AdaBoostClassifier: Stoke test accuracy are: 50.0
# BaggingClassifier: Stoke validation accuracy are: 47.368421052631575
# BaggingClassifier: Stoke test accuracy are: 47.368421052631575
# ExtraTreesClassifier: Stoke validation accuracy are: 44.73684210526316
# ExtraTreesClassifier: Stoke test accuracy are: 44.73684210526316
# GradientBoostingClassifier: Stoke validation accuracy are: 42.10526315789473
# GradientBoostingClassifier: Stoke test accuracy are: 42.10526315789473
# ***Best validate classifier is LogisticRegression 50.0
# ***Best test classifier is AdaBoostClassifier 50.0
# -------------------------
# skip Sunderland
# LogisticRegression: Swansea validation accuracy are: 55.26315789473685
# LogisticRegression: Swansea test accuracy are: 36.84210526315789
# RandomForestClassifier: Swansea validation accuracy are: 55.26315789473685
# RandomForestClassifier: Swansea test accuracy are: 55.26315789473685
# AdaBoostClassifier: Swansea validation accuracy are: 50.0
# AdaBoostClassifier: Swansea test accuracy are: 50.0
# BaggingClassifier: Swansea validation accuracy are: 60.526315789473685
# BaggingClassifier: Swansea test accuracy are: 60.526315789473685
# ExtraTreesClassifier: Swansea validation accuracy are: 34.21052631578947
# ExtraTreesClassifier: Swansea test accuracy are: 34.21052631578947
# GradientBoostingClassifier: Swansea validation accuracy are: 50.0
# GradientBoostingClassifier: Swansea test accuracy are: 50.0
# ***Best validate classifier is BaggingClassifier 60.526315789473685
# ***Best test classifier is BaggingClassifier 60.526315789473685
# -------------------------
# LogisticRegression: Tottenham validation accuracy are: 68.42105263157895
# LogisticRegression: Tottenham test accuracy are: 63.1578947368421
# RandomForestClassifier: Tottenham validation accuracy are: 39.473684210526315
# RandomForestClassifier: Tottenham test accuracy are: 39.473684210526315
# AdaBoostClassifier: Tottenham validation accuracy are: 42.10526315789473
# AdaBoostClassifier: Tottenham test accuracy are: 42.10526315789473
# BaggingClassifier: Tottenham validation accuracy are: 50.0
# BaggingClassifier: Tottenham test accuracy are: 50.0
# ExtraTreesClassifier: Tottenham validation accuracy are: 42.10526315789473
# ExtraTreesClassifier: Tottenham test accuracy are: 42.10526315789473
# GradientBoostingClassifier: Tottenham validation accuracy are: 44.73684210526316
# GradientBoostingClassifier: Tottenham test accuracy are: 44.73684210526316
# ***Best validate classifier is LogisticRegression 68.42105263157895
# ***Best test classifier is LogisticRegression 63.1578947368421
# -------------------------
# LogisticRegression: Watford validation accuracy are: 57.89473684210527
# LogisticRegression: Watford test accuracy are: 36.84210526315789
# RandomForestClassifier: Watford validation accuracy are: 55.26315789473685
# RandomForestClassifier: Watford test accuracy are: 55.26315789473685
# AdaBoostClassifier: Watford validation accuracy are: 52.63157894736842
# AdaBoostClassifier: Watford test accuracy are: 52.63157894736842
# BaggingClassifier: Watford validation accuracy are: 55.26315789473685
# BaggingClassifier: Watford test accuracy are: 55.26315789473685
# ExtraTreesClassifier: Watford validation accuracy are: 47.368421052631575
# ExtraTreesClassifier: Watford test accuracy are: 47.368421052631575
# GradientBoostingClassifier: Watford validation accuracy are: 52.63157894736842
# GradientBoostingClassifier: Watford test accuracy are: 52.63157894736842
# ***Best validate classifier is LogisticRegression 57.89473684210527
# ***Best test classifier is RandomForestClassifier 55.26315789473685
# -------------------------
# LogisticRegression: West Brom validation accuracy are: 55.26315789473685
# LogisticRegression: West Brom test accuracy are: 28.947368421052634
# RandomForestClassifier: West Brom validation accuracy are: 36.84210526315789
# RandomForestClassifier: West Brom test accuracy are: 36.84210526315789
# AdaBoostClassifier: West Brom validation accuracy are: 39.473684210526315
# AdaBoostClassifier: West Brom test accuracy are: 39.473684210526315
# BaggingClassifier: West Brom validation accuracy are: 31.57894736842105
# BaggingClassifier: West Brom test accuracy are: 31.57894736842105
# ExtraTreesClassifier: West Brom validation accuracy are: 44.73684210526316
# ExtraTreesClassifier: West Brom test accuracy are: 44.73684210526316
# GradientBoostingClassifier: West Brom validation accuracy are: 39.473684210526315
# GradientBoostingClassifier: West Brom test accuracy are: 39.473684210526315
# ***Best validate classifier is LogisticRegression 55.26315789473685
# ***Best test classifier is ExtraTreesClassifier 44.73684210526316
# -------------------------
# LogisticRegression: West Ham validation accuracy are: 52.63157894736842
# LogisticRegression: West Ham test accuracy are: 42.10526315789473
# RandomForestClassifier: West Ham validation accuracy are: 28.947368421052634
# RandomForestClassifier: West Ham test accuracy are: 28.947368421052634
# AdaBoostClassifier: West Ham validation accuracy are: 34.21052631578947
# AdaBoostClassifier: West Ham test accuracy are: 34.21052631578947
# BaggingClassifier: West Ham validation accuracy are: 26.31578947368421
# BaggingClassifier: West Ham test accuracy are: 26.31578947368421
# ExtraTreesClassifier: West Ham validation accuracy are: 42.10526315789473
# ExtraTreesClassifier: West Ham test accuracy are: 42.10526315789473
# GradientBoostingClassifier: West Ham validation accuracy are: 47.368421052631575
# GradientBoostingClassifier: West Ham test accuracy are: 47.368421052631575
# ***Best validate classifier is LogisticRegression 52.63157894736842
# ***Best test classifier is GradientBoostingClassifier 47.368421052631575
# -------------------------

# %%
for key, groupByPredictor in total.groupby('predictor'):
    print(f"{key} overall accuracy is ", accuracy_score(groupByPredictor['actual'], groupByPredictor['pred'])*100)
# Out:
# AdaBoostClassifier overall accuracy is  50.77399380804953
# BaggingClassifier overall accuracy is  48.297213622291025
# ExtraTreesClassifier overall accuracy is  45.356037151702786
# GradientBoostingClassifier overall accuracy is  50.61919504643962
# LogisticRegression overall accuracy is  50.30959752321982
# RandomForestClassifier overall accuracy is  49.07120743034056
